# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('RecordsAnno4.csv')
dfx = df[(df.Duration>=97.0) & (df.Duration<=100.0)]
display(dfx)
# Out:
#      RecordNum  PatientId  ICUStayId  HadmId  RespDisease   Age Gender  \
# 185    3154375       5494     200179  194854         True  86.0      M
# 353    3879143      10525     264495  159935        False  86.0      F
# 369    3917239      10985     256700  173020        False  42.0      M
# 566    3570017      42510     295408  161943        False  75.0      M
# 636    3914668      45434     282176  131621         True  60.0      M
# 850    3792584      53714     256733  156019         True  75.0      M
# 852    3593020      53722     276727  188000        False  86.0      M
# 894    3687929      54979     258288  128748        False  79.0      M
#
#      LastStay  Mortality  Ventilator  ...  SamplingRate  \
# 185      True       True       False  ...             1
# 353      True      False       False  ...             1
# 369      True      False       False  ...             1
# 566     False      False       False  ...             1
# ...

# %%
dfx = df[df.Category=='X']
display(dfx)
# Out:
#      RecordNum  PatientId  ICUStayId  HadmId  RespDisease   Age Gender  \
# 7      3502927        214     241941  197273         True  64.0      M
# 22     3066921        695     289542  177128         True  85.0      F
# 42     3814084       1021     254654  154151         True  74.0      M
# 53     3401436       1453     233088  135399         True  49.0      F
# 65     3676141       1900     287745  116403         True  59.0      M
# 79     3248264       2246     206293  182109         True  50.0      F
# 94     3090785       2639     200972  158120         True  66.0      F
# 100    3133115       2773     263226  172324         True  66.0      F
# 111    3777753       3084     224237  112452         True  63.0      F
# 131    3275873       3939     227004  159577         True  69.0      F
# 137    3921446       4113     264074  182591         True  46.0      F
# 173    3973169       5195     247339  113772         True  66.0      M
# ...

# %%
def plot_rocauc(y_test,y_test,model):
    logit_roc_auc = roc_auc_score(y_test, model.predict(X_test))
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1])
    plt.figure()
    plt.plot(fpr, tpr, label='LGB (area = %0.2f)' % logit_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    #plt.savefig('Log_ROC')
    plt.show()

# %%
from tqdm.notebook import tqdm
i=0
for x in tqdm(range(100)):
    i+=1

# %%
for n, id_ in tqdm.notebook.tqdm(enumerate(ids), total=len(ids)):
